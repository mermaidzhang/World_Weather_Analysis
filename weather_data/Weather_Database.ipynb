# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bf5906bae2533751a55ca9003927fa34

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":  city_description,
                          "Country": city_country,
                          "Date": city_date})
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | nanakuli
# Processing Record 7 of Set 1 | tongren
# Processing Record 8 of Set 1 | saldanha
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | sarankhola
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | leningradskiy
# Processing Record 15 of Set 1 | katete
# Processing Record 16 of Set 1 | coquimbo
# Processing Record 17 of Set 1 | hobyo
# Processing Record 18 of Set 1 | limbang
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | hua hin
# Processing Record 21 of Set 1 | mount gambier
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | vanimo
# Processing Record 26 of Set 1 | lorengau
# Processing Record 27 of Set 1 | broken hill
# Processing Record 28 of Set 1 | dryden
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | hami
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | la quinta
# Processing Record 33 of Set 1 | torbay
# Processing Record 34 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 1 | ahipara
# Processing Record 36 of Set 1 | kaitangata
# Processing Record 37 of Set 1 | tuy hoa
# Processing Record 38 of Set 1 | berlevag
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | praia da vitoria
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | miles city
# Processing Record 43 of Set 1 | stafford
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | altamira
# Processing Record 48 of Set 1 | chama
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | oranjestad
# Processing Record 1 of Set 2 | barranca
# Processing Record 2 of Set 2 | tigre
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | faanui
# Processing Record 5 of Set 2 | lagoa
# Processing Record 6 of Set 2 | hambantota
# Processing Record 7 of Set 2 | ostersund
# Processing Record 8 of Set 2 | nicoya
# Processing Record 9 of Set 2 | college
# Processing Record 10 of Set 2 | bethanien
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | am timan
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | dergachi
# Processing Record 17 of Set 2 | iqaluit
# Processing Record 18 of Set 2 | kaeo
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | chalchihuites
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | mandalgovi
# Processing Record 23 of Set 2 | gat
# Processing Record 24 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 25 of Set 2 | gushikawa
# Processing Record 26 of Set 2 | mao
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | mogadishu
# Processing Record 32 of Set 2 | london
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | teodoro sampaio
# Processing Record 38 of Set 2 | albany
# Processing Record 39 of Set 2 | saskylakh
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | clyde river
# Processing Record 45 of Set 2 | takoradi
# Processing Record 46 of Set 2 | umm kaddadah
# Processing Record 47 of Set 2 | kalamb
# Processing Record 48 of Set 2 | ulaangom
# Processing Record 49 of Set 2 | victoria point
# Processing Record 50 of Set 2 | sitka
# Processing Record 1 of Set 3 | rundu
# Processing Record 2 of Set 3 | kodiak
# Processing Record 3 of Set 3 | bandarbeyla
# Processing Record 4 of Set 3 | nome
# Processing Record 5 of Set 3 | erzin
# Processing Record 6 of Set 3 | vostok
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | price
# Processing Record 9 of Set 3 | sitio novo do tocantins
# Processing Record 10 of Set 3 | ponta do sol
# Processing Record 11 of Set 3 | pascagoula
# Processing Record 12 of Set 3 | sao cristovao
# Processing Record 13 of Set 3 | maceio
# Processing Record 14 of Set 3 | haines junction
# Processing Record 15 of Set 3 | fare
# Processing Record 16 of Set 3 | taoudenni
# Processing Record 17 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 3 | portland
# Processing Record 19 of Set 3 | atar
# Processing Record 20 of Set 3 | ormara
# Processing Record 21 of Set 3 | launceston
# Processing Record 22 of Set 3 | aleksandrov gay
# Processing Record 23 of Set 3 | reinosa
# Processing Record 24 of Set 3 | stony brook
# Processing Record 25 of Set 3 | karratha
# Processing Record 26 of Set 3 | hennigsdorf
# Processing Record 27 of Set 3 | katra
# Processing Record 28 of Set 3 | mahebourg
# Processing Record 29 of Set 3 | la grande
# Processing Record 30 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 3 | port keats
# Processing Record 33 of Set 3 | andenes
# Processing Record 34 of Set 3 | locri
# Processing Record 35 of Set 3 | havre-saint-pierre
# Processing Record 36 of Set 3 | korla
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | nhulunbuy
# Processing Record 39 of Set 3 | vaini
# Processing Record 40 of Set 3 | kavaratti
# Processing Record 41 of Set 3 | buin
# Processing Record 42 of Set 3 | qaanaaq
# Processing Record 43 of Set 3 | kahului
# Processing Record 44 of Set 3 | popondetta
# Processing Record 45 of Set 3 | hasaki
# Processing Record 46 of Set 3 | alushta
# Processing Record 47 of Set 3 | srandakan
# Processing Record 48 of Set 3 | kisanga
# Processing Record 49 of Set 3 | nikolskoye
# Processing Record 50 of Set 3 | bacolod
# Processing Record 1 of Set 4 | jilib
# Processing Record 2 of Set 4 | chokurdakh
# Processing Record 3 of Set 4 | ylojarvi
# Processing Record 4 of Set 4 | bull savanna
# Processing Record 5 of Set 4 | jamestown
# Processing Record 6 of Set 4 | pisco
# Processing Record 7 of Set 4 | piacabucu
# Processing Record 8 of Set 4 | omsukchan
# Processing Record 9 of Set 4 | vila velha
# Processing Record 10 of Set 4 | zyuzelskiy
# Processing Record 11 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 4 | humaita
# Processing Record 13 of Set 4 | taft
# Processing Record 14 of Set 4 | maragogi
# Processing Record 15 of Set 4 | agadir
# Processing Record 16 of Set 4 | itarema
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | kasangulu
# Processing Record 19 of Set 4 | puerto ayora
# Processing Record 20 of Set 4 | kargasok
# Processing Record 21 of Set 4 | araouane
# Processing Record 22 of Set 4 | new norfolk
# Processing Record 23 of Set 4 | sahrak
# City not found. Skipping...
# Processing Record 24 of Set 4 | minot
# Processing Record 25 of Set 4 | mokhsogollokh
# Processing Record 26 of Set 4 | sakakah
# Processing Record 27 of Set 4 | merauke
# Processing Record 28 of Set 4 | brownsville
# Processing Record 29 of Set 4 | grand-santi
# Processing Record 30 of Set 4 | durant
# Processing Record 31 of Set 4 | sernovodsk
# Processing Record 32 of Set 4 | coolum beach
# Processing Record 33 of Set 4 | jalu
# Processing Record 34 of Set 4 | katsuura
# Processing Record 35 of Set 4 | paka
# Processing Record 36 of Set 4 | gaoual
# Processing Record 37 of Set 4 | charagua
# Processing Record 38 of Set 4 | shubarkuduk
# Processing Record 39 of Set 4 | hualmay
# Processing Record 40 of Set 4 | yumen
# Processing Record 41 of Set 4 | sparti
# Processing Record 42 of Set 4 | thompson
# Processing Record 43 of Set 4 | provideniya
# Processing Record 44 of Set 4 | mareeba
# Processing Record 45 of Set 4 | hailar
# Processing Record 46 of Set 4 | tiksi
# Processing Record 47 of Set 4 | lebu
# Processing Record 48 of Set 4 | albacete
# Processing Record 49 of Set 4 | kulhudhuffushi
# Processing Record 50 of Set 4 | luanda
# Processing Record 1 of Set 5 | santa rosalia
# Processing Record 2 of Set 5 | bengkulu
# Processing Record 3 of Set 5 | miquelon
# Processing Record 4 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | yichang
# Processing Record 7 of Set 5 | isangel
# Processing Record 8 of Set 5 | vanavara
# Processing Record 9 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 5 | thunder bay
# Processing Record 11 of Set 5 | saint-michel-des-saints
# Processing Record 12 of Set 5 | olavarria
# Processing Record 13 of Set 5 | benghazi
# Processing Record 14 of Set 5 | rio grande
# Processing Record 15 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 5 | xuddur
# Processing Record 17 of Set 5 | katherine
# Processing Record 18 of Set 5 | half moon bay
# Processing Record 19 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 5 | gladstone
# Processing Record 21 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 5 | kavieng
# Processing Record 23 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 24 of Set 5 | tibiri
# Processing Record 25 of Set 5 | tahta
# Processing Record 26 of Set 5 | longyearbyen
# Processing Record 27 of Set 5 | sosnovo-ozerskoye
# Processing Record 28 of Set 5 | khandyga
# Processing Record 29 of Set 5 | quelimane
# Processing Record 30 of Set 5 | matamoros
# Processing Record 31 of Set 5 | kimbe
# Processing Record 32 of Set 5 | palu
# Processing Record 33 of Set 5 | skibbereen
# Processing Record 34 of Set 5 | bambanglipuro
# Processing Record 35 of Set 5 | san quintin
# Processing Record 36 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 37 of Set 5 | vao
# Processing Record 38 of Set 5 | otradnoye
# Processing Record 39 of Set 5 | constitucion
# Processing Record 40 of Set 5 | waipawa
# Processing Record 41 of Set 5 | oga
# Processing Record 42 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 5 | kamaishi
# Processing Record 44 of Set 5 | konstantinovka
# Processing Record 45 of Set 5 | souillac
# Processing Record 46 of Set 5 | sao filipe
# Processing Record 47 of Set 5 | tautira
# Processing Record 48 of Set 5 | perth
# Processing Record 49 of Set 5 | salalah
# Processing Record 50 of Set 5 | bodden town
# Processing Record 1 of Set 6 | geraldton
# Processing Record 2 of Set 6 | upernavik
# Processing Record 3 of Set 6 | kitgum
# Processing Record 4 of Set 6 | tecoanapa
# Processing Record 5 of Set 6 | miri
# Processing Record 6 of Set 6 | sacama
# Processing Record 7 of Set 6 | teya
# Processing Record 8 of Set 6 | zyryanka
# Processing Record 9 of Set 6 | yulara
# Processing Record 10 of Set 6 | mujiayingzi
# Processing Record 11 of Set 6 | akropong
# Processing Record 12 of Set 6 | nanortalik
# Processing Record 13 of Set 6 | kirkcudbright
# Processing Record 14 of Set 6 | dicabisagan
# Processing Record 15 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 6 | balkanabat
# Processing Record 18 of Set 6 | horsham
# Processing Record 19 of Set 6 | noumea
# Processing Record 20 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 6 | balabac
# Processing Record 22 of Set 6 | port-gentil
# Processing Record 23 of Set 6 | qaqortoq
# Processing Record 24 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 6 | aleksandrovsk-sakhalinskiy
# Processing Record 26 of Set 6 | igbaras
# Processing Record 27 of Set 6 | angra
# City not found. Skipping...
# Processing Record 28 of Set 6 | akdepe
# Processing Record 29 of Set 6 | los llanos de aridane
# Processing Record 30 of Set 6 | cusuna
# Processing Record 31 of Set 6 | dong xoai
# Processing Record 32 of Set 6 | rocha
# Processing Record 33 of Set 6 | roald
# Processing Record 34 of Set 6 | cherskiy
# Processing Record 35 of Set 6 | cascais
# Processing Record 36 of Set 6 | lompoc
# Processing Record 37 of Set 6 | lasa
# Processing Record 38 of Set 6 | olds
# Processing Record 39 of Set 6 | dikson
# Processing Record 40 of Set 6 | namatanai
# Processing Record 41 of Set 6 | chapais
# Processing Record 42 of Set 6 | bud
# Processing Record 43 of Set 6 | sarangani
# Processing Record 44 of Set 6 | palpa
# Processing Record 45 of Set 6 | bida
# Processing Record 46 of Set 6 | saint george
# Processing Record 47 of Set 6 | coihaique
# Processing Record 48 of Set 6 | waddan
# Processing Record 49 of Set 6 | revadanda
# Processing Record 50 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 7 | ploemeur
# Processing Record 2 of Set 7 | tezu
# Processing Record 3 of Set 7 | husavik
# Processing Record 4 of Set 7 | mariental
# Processing Record 5 of Set 7 | privolzhskiy
# Processing Record 6 of Set 7 | bahia honda
# Processing Record 7 of Set 7 | pekan
# Processing Record 8 of Set 7 | ribas do rio pardo
# Processing Record 9 of Set 7 | gravdal
# Processing Record 10 of Set 7 | stromness
# Processing Record 11 of Set 7 | durazno
# Processing Record 12 of Set 7 | hofn
# Processing Record 13 of Set 7 | tuatapere
# Processing Record 14 of Set 7 | kirakira
# Processing Record 15 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 7 | mezen
# Processing Record 17 of Set 7 | udachnyy
# Processing Record 18 of Set 7 | chimoio
# Processing Record 19 of Set 7 | gazanjyk
# Processing Record 20 of Set 7 | seminole
# Processing Record 21 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 7 | keningau
# Processing Record 23 of Set 7 | vyshhorod
# Processing Record 24 of Set 7 | demir hisar
# Processing Record 25 of Set 7 | margau
# Processing Record 26 of Set 7 | minab
# Processing Record 27 of Set 7 | saint-joseph
# Processing Record 28 of Set 7 | lata
# Processing Record 29 of Set 7 | isla mujeres
# Processing Record 30 of Set 7 | shimoda
# Processing Record 31 of Set 7 | dingle
# Processing Record 32 of Set 7 | brzi brod
# City not found. Skipping...
# Processing Record 33 of Set 7 | solnechnyy
# Processing Record 34 of Set 7 | touros
# Processing Record 35 of Set 7 | poddorye
# Processing Record 36 of Set 7 | lake city
# Processing Record 37 of Set 7 | te anau
# Processing Record 38 of Set 7 | kysyl-syr
# Processing Record 39 of Set 7 | dunmore east
# Processing Record 40 of Set 7 | aswan
# Processing Record 41 of Set 7 | sayyan
# Processing Record 42 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 7 | avera
# Processing Record 44 of Set 7 | dudinka
# Processing Record 45 of Set 7 | cortez
# Processing Record 46 of Set 7 | baykit
# Processing Record 47 of Set 7 | caravelas
# Processing Record 48 of Set 7 | san angelo
# Processing Record 49 of Set 7 | agadez
# Processing Record 50 of Set 7 | makokou
# Processing Record 1 of Set 8 | yekimovichi
# Processing Record 2 of Set 8 | antri
# Processing Record 3 of Set 8 | port hedland
# Processing Record 4 of Set 8 | les mureaux
# Processing Record 5 of Set 8 | koslan
# Processing Record 6 of Set 8 | san patricio
# Processing Record 7 of Set 8 | tingo maria
# Processing Record 8 of Set 8 | east london
# Processing Record 9 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 8 | narsaq
# Processing Record 11 of Set 8 | sidi ali
# Processing Record 12 of Set 8 | kozhva
# Processing Record 13 of Set 8 | namibe
# Processing Record 14 of Set 8 | ca mau
# Processing Record 15 of Set 8 | naze
# Processing Record 16 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 17 of Set 8 | muros
# Processing Record 18 of Set 8 | brae
# Processing Record 19 of Set 8 | homer
# Processing Record 20 of Set 8 | porto novo
# Processing Record 21 of Set 8 | atarfe
# Processing Record 22 of Set 8 | zhigansk
# Processing Record 23 of Set 8 | verkhnevilyuysk
# Processing Record 24 of Set 8 | mier
# Processing Record 25 of Set 8 | hokitika
# Processing Record 26 of Set 8 | ambulu
# Processing Record 27 of Set 8 | westport
# Processing Record 28 of Set 8 | tchollire
# Processing Record 29 of Set 8 | mount isa
# Processing Record 30 of Set 8 | sabang
# Processing Record 31 of Set 8 | zatoka
# Processing Record 32 of Set 8 | nenjiang
# Processing Record 33 of Set 8 | kiama
# Processing Record 34 of Set 8 | harwich
# Processing Record 35 of Set 8 | praia
# Processing Record 36 of Set 8 | lagos
# Processing Record 37 of Set 8 | tessalit
# Processing Record 38 of Set 8 | samarai
# Processing Record 39 of Set 8 | alihe
# Processing Record 40 of Set 8 | colares
# Processing Record 41 of Set 8 | galesong
# Processing Record 42 of Set 8 | dharmadam
# Processing Record 43 of Set 8 | lovozero
# Processing Record 44 of Set 8 | isilkul
# Processing Record 45 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 8 | mineiros
# Processing Record 47 of Set 8 | mahajanga
# Processing Record 48 of Set 8 | dingli
# Processing Record 49 of Set 8 | salinopolis
# Processing Record 50 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 9 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 2 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 3 of Set 9 | cayenne
# Processing Record 4 of Set 9 | mantua
# Processing Record 5 of Set 9 | pangnirtung
# Processing Record 6 of Set 9 | bathsheba
# Processing Record 7 of Set 9 | rosarito
# Processing Record 8 of Set 9 | kirishi
# Processing Record 9 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 10 of Set 9 | cozumel
# Processing Record 11 of Set 9 | amberley
# Processing Record 12 of Set 9 | fort carson
# Processing Record 13 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 9 | coaldale
# Processing Record 15 of Set 9 | bani walid
# Processing Record 16 of Set 9 | palauig
# Processing Record 17 of Set 9 | williamsport
# Processing Record 18 of Set 9 | ewa beach
# Processing Record 19 of Set 9 | magam
# Processing Record 20 of Set 9 | okha
# Processing Record 21 of Set 9 | nogliki
# Processing Record 22 of Set 9 | tangshan
# Processing Record 23 of Set 9 | grand gaube
# Processing Record 24 of Set 9 | faya
# Processing Record 25 of Set 9 | port lincoln
# Processing Record 26 of Set 9 | cidreira
# Processing Record 27 of Set 9 | eyl
# Processing Record 28 of Set 9 | yining
# Processing Record 29 of Set 9 | general roca
# Processing Record 30 of Set 9 | bubaque
# Processing Record 31 of Set 9 | pribelskiy
# City not found. Skipping...
# Processing Record 32 of Set 9 | ust-maya
# Processing Record 33 of Set 9 | talcahuano
# Processing Record 34 of Set 9 | chuy
# Processing Record 35 of Set 9 | crawfordsville
# Processing Record 36 of Set 9 | pemberton
# Processing Record 37 of Set 9 | kalmunai
# Processing Record 38 of Set 9 | buala
# Processing Record 39 of Set 9 | yeppoon
# Processing Record 40 of Set 9 | port blair
# Processing Record 41 of Set 9 | ancud
# Processing Record 42 of Set 9 | macas
# Processing Record 43 of Set 9 | talnakh
# Processing Record 44 of Set 9 | pingliang
# Processing Record 45 of Set 9 | mazyr
# Processing Record 46 of Set 9 | vestmannaeyjar
# Processing Record 47 of Set 9 | kindersley
# Processing Record 48 of Set 9 | mazatlan
# Processing Record 49 of Set 9 | gucheng
# Processing Record 50 of Set 9 | santa maria
# Processing Record 1 of Set 10 | mingguang
# Processing Record 2 of Set 10 | madhipura
# Processing Record 3 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 4 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 10 | sorland
# Processing Record 6 of Set 10 | sisophon
# Processing Record 7 of Set 10 | bugalagrande
# Processing Record 8 of Set 10 | zwedru
# Processing Record 9 of Set 10 | ozernovskiy
# Processing Record 10 of Set 10 | suntar
# Processing Record 11 of Set 10 | marzuq
# Processing Record 12 of Set 10 | mandan
# Processing Record 13 of Set 10 | rawson
# Processing Record 14 of Set 10 | kilindoni
# Processing Record 15 of Set 10 | adrar
# Processing Record 16 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 10 | sur
# Processing Record 18 of Set 10 | warah
# Processing Record 19 of Set 10 | bosconia
# Processing Record 20 of Set 10 | nador
# Processing Record 21 of Set 10 | goderich
# Processing Record 22 of Set 10 | alibag
# Processing Record 23 of Set 10 | severo-kurilsk
# Processing Record 24 of Set 10 | saint anthony
# Processing Record 25 of Set 10 | formosa
# Processing Record 26 of Set 10 | cap malheureux
# Processing Record 27 of Set 10 | carutapera
# Processing Record 28 of Set 10 | nelson bay
# Processing Record 29 of Set 10 | singaraja
# Processing Record 30 of Set 10 | dobroye
# Processing Record 31 of Set 10 | henties bay
# Processing Record 32 of Set 10 | la malbaie
# Processing Record 33 of Set 10 | davila
# Processing Record 34 of Set 10 | beba
# Processing Record 35 of Set 10 | axim
# Processing Record 36 of Set 10 | sento se
# City not found. Skipping...
# Processing Record 37 of Set 10 | martapura
# Processing Record 38 of Set 10 | kaura namoda
# Processing Record 39 of Set 10 | richards bay
# Processing Record 40 of Set 10 | quatre cocos
# Processing Record 41 of Set 10 | lavrentiya
# Processing Record 42 of Set 10 | coffs harbour
# Processing Record 43 of Set 10 | laguna
# Processing Record 44 of Set 10 | mega
# Processing Record 45 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 46 of Set 10 | kiunga
# Processing Record 47 of Set 10 | nouadhibou
# Processing Record 48 of Set 10 | sisimiut
# Processing Record 49 of Set 10 | oleksandrivka
# Processing Record 50 of Set 10 | gunjur
# Processing Record 1 of Set 11 | merritt
# Processing Record 2 of Set 11 | dauriya
# Processing Record 3 of Set 11 | darnah
# Processing Record 4 of Set 11 | guelengdeng
# City not found. Skipping...
# Processing Record 5 of Set 11 | khani
# Processing Record 6 of Set 11 | sao miguel do guama
# Processing Record 7 of Set 11 | ciudad bolivar
# Processing Record 8 of Set 11 | nabire
# Processing Record 9 of Set 11 | ust-tsilma
# Processing Record 10 of Set 11 | kombissiri
# Processing Record 11 of Set 11 | bauchi
# Processing Record 12 of Set 11 | la maddalena
# Processing Record 13 of Set 11 | zelenogorskiy
# Processing Record 14 of Set 11 | srednekolymsk
# Processing Record 15 of Set 11 | matara
# Processing Record 16 of Set 11 | shingu
# Processing Record 17 of Set 11 | necochea
# Processing Record 18 of Set 11 | ofunato
# Processing Record 19 of Set 11 | mae sai
# Processing Record 20 of Set 11 | kovdor
# Processing Record 21 of Set 11 | kapit
# Processing Record 22 of Set 11 | clifton
# Processing Record 23 of Set 11 | markova
# Processing Record 24 of Set 11 | del rio
# Processing Record 25 of Set 11 | makakilo city
# Processing Record 26 of Set 11 | guerrero negro
# Processing Record 27 of Set 11 | nishihara
# Processing Record 28 of Set 11 | dawei
# Processing Record 29 of Set 11 | kieta
# Processing Record 30 of Set 11 | anloga
# Processing Record 31 of Set 11 | pampa
# Processing Record 32 of Set 11 | lom sak
# Processing Record 33 of Set 11 | riyadh
# Processing Record 34 of Set 11 | sibolga
# Processing Record 35 of Set 11 | belaya gora
# Processing Record 36 of Set 11 | praya
# Processing Record 37 of Set 11 | muisne
# Processing Record 38 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 11 | sturgeon bay
# Processing Record 40 of Set 11 | naron
# Processing Record 41 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 11 | cherepovets
# Processing Record 43 of Set 11 | norman wells
# Processing Record 44 of Set 11 | talhar
# Processing Record 45 of Set 11 | boyuibe
# Processing Record 46 of Set 11 | santa rosa
# Processing Record 47 of Set 11 | magdalena
# Processing Record 48 of Set 11 | rebrikha
# Processing Record 49 of Set 11 | bara
# Processing Record 50 of Set 11 | chekhov
# Processing Record 1 of Set 12 | lethem
# Processing Record 2 of Set 12 | muroto
# Processing Record 3 of Set 12 | mbini
# Processing Record 4 of Set 12 | port hardy
# Processing Record 5 of Set 12 | urusha
# Processing Record 6 of Set 12 | bahia blanca
# Processing Record 7 of Set 12 | ambon
# Processing Record 8 of Set 12 | lumberton
# Processing Record 9 of Set 12 | sakaiminato
# Processing Record 10 of Set 12 | santa isabel
# Processing Record 11 of Set 12 | santa quiteria do maranhao
# Processing Record 12 of Set 12 | krasnyy chikoy
# Processing Record 13 of Set 12 | calama
# Processing Record 14 of Set 12 | parana
# Processing Record 15 of Set 12 | poum
# Processing Record 16 of Set 12 | wukari
# Processing Record 17 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 12 | vernon
# Processing Record 19 of Set 12 | aanekoski
# Processing Record 20 of Set 12 | torrington
# Processing Record 21 of Set 12 | broome
# Processing Record 22 of Set 12 | pochinki
# Processing Record 23 of Set 12 | kushima
# Processing Record 24 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 12 | eydhafushi
# Processing Record 27 of Set 12 | trinidad
# Processing Record 28 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 12 | yar-sale
# Processing Record 30 of Set 12 | mitu
# Processing Record 31 of Set 12 | uberaba
# Processing Record 32 of Set 12 | teresa
# Processing Record 33 of Set 12 | taikang
# Processing Record 34 of Set 12 | marsa matruh
# Processing Record 35 of Set 12 | pimentel
# Processing Record 36 of Set 12 | lyantonde
# Processing Record 37 of Set 12 | zheleznodorozhnyy
# Processing Record 38 of Set 12 | chaa-khol
# City not found. Skipping...
# Processing Record 39 of Set 12 | barra dos coqueiros
# Processing Record 40 of Set 12 | huarmey
# Processing Record 41 of Set 12 | chopda
# Processing Record 42 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 12 | dongfeng
# Processing Record 44 of Set 12 | basudebpur
# Processing Record 45 of Set 12 | myrtle beach
# Processing Record 46 of Set 12 | toda bhim
# City not found. Skipping...
# Processing Record 47 of Set 12 | ushtobe
# Processing Record 48 of Set 12 | vitina
# Processing Record 49 of Set 12 | deputatskiy
# Processing Record 50 of Set 12 | omboue
# Processing Record 1 of Set 13 | cabinda
# Processing Record 2 of Set 13 | warrington
# Processing Record 3 of Set 13 | puerto del rosario
# Processing Record 4 of Set 13 | puerto baquerizo moreno
# Processing Record 5 of Set 13 | soligalich
# Processing Record 6 of Set 13 | gubkinskiy
# Processing Record 7 of Set 13 | elyria
# Processing Record 8 of Set 13 | kazachinskoye
# Processing Record 9 of Set 13 | alice springs
# Processing Record 10 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 11 of Set 13 | mayo
# Processing Record 12 of Set 13 | saint charles
# Processing Record 13 of Set 13 | camacha
# Processing Record 14 of Set 13 | sabha
# Processing Record 15 of Set 13 | borlange
# City not found. Skipping...
# Processing Record 16 of Set 13 | presidencia roque saenz pena
# Processing Record 17 of Set 13 | port-cartier
# Processing Record 18 of Set 13 | falan
# Processing Record 19 of Set 13 | rio gallegos
# Processing Record 20 of Set 13 | sabzevar
# Processing Record 21 of Set 13 | sobolevo
# Processing Record 22 of Set 13 | lewistown
# Processing Record 23 of Set 13 | gamba
# Processing Record 24 of Set 13 | sao desiderio
# Processing Record 25 of Set 13 | neulengbach
# Processing Record 26 of Set 13 | mirabad
# Processing Record 27 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 28 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 13 | idrinskoye
# Processing Record 30 of Set 13 | dukat
# Processing Record 31 of Set 13 | dhidhdhoo
# Processing Record 32 of Set 13 | lucea
# Processing Record 33 of Set 13 | bukene
# Processing Record 34 of Set 13 | malanje
# Processing Record 35 of Set 13 | fukue
# Processing Record 36 of Set 13 | marechal deodoro
# Processing Record 37 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 13 | luderitz
# Processing Record 39 of Set 13 | riohacha
# Processing Record 40 of Set 13 | moron
# Processing Record 41 of Set 13 | sala consilina
# Processing Record 42 of Set 13 | pinega
# Processing Record 43 of Set 13 | beyneu
# Processing Record 44 of Set 13 | biltine
# Processing Record 45 of Set 13 | amatan
# Processing Record 46 of Set 13 | sokolovo
# Processing Record 47 of Set 13 | iracoubo
# Processing Record 48 of Set 13 | plouzane
# Processing Record 49 of Set 13 | rosita
# Processing Record 50 of Set 13 | pundaguitan
# Processing Record 1 of Set 14 | burnie
# Processing Record 2 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 14 | huazolotitlan
# City not found. Skipping...
# Processing Record 4 of Set 14 | arlit
# Processing Record 5 of Set 14 | bhimunipatnam
# Processing Record 6 of Set 14 | aklavik
# Processing Record 7 of Set 14 | cocobeach
# Processing Record 8 of Set 14 | flinders
# Processing Record 9 of Set 14 | la romana
# Processing Record 10 of Set 14 | muslyumovo
# Processing Record 11 of Set 14 | nelson
# Processing Record 12 of Set 14 | pakwach
# City not found. Skipping...
# Processing Record 13 of Set 14 | sao felix do xingu
# Processing Record 14 of Set 14 | flin flon
# Processing Record 15 of Set 14 | turayf
# Processing Record 16 of Set 14 | posse
# Processing Record 17 of Set 14 | kisangani
# Processing Record 18 of Set 14 | talara
# Processing Record 19 of Set 14 | niamey
# Processing Record 20 of Set 14 | victor harbor
# Processing Record 21 of Set 14 | puerto maldonado
# Processing Record 22 of Set 14 | chumikan
# Processing Record 23 of Set 14 | cockburn town
# Processing Record 24 of Set 14 | guarapari
# Processing Record 25 of Set 14 | tepatlaxco
# Processing Record 26 of Set 14 | labuhan
# Processing Record 27 of Set 14 | talaya
# Processing Record 28 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 29 of Set 14 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 30 of Set 14 | manga
# Processing Record 31 of Set 14 | oni
# Processing Record 32 of Set 14 | kalawit
# Processing Record 33 of Set 14 | kabo
# Processing Record 34 of Set 14 | chantada
# Processing Record 35 of Set 14 | moranbah
# Processing Record 36 of Set 14 | mecca
# Processing Record 37 of Set 14 | hovd
# Processing Record 38 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 14 | sussex
# Processing Record 40 of Set 14 | ostrovnoy
# Processing Record 41 of Set 14 | yaya
# Processing Record 42 of Set 14 | wichian buri
# Processing Record 43 of Set 14 | kazerun
# Processing Record 44 of Set 14 | temirtau
# Processing Record 45 of Set 14 | ereymentau
# Processing Record 46 of Set 14 | genhe
# Processing Record 47 of Set 14 | dunedin
# Processing Record 48 of Set 14 | pamekasan
# Processing Record 49 of Set 14 | gelemso
# Processing Record 50 of Set 14 | eltham
# Processing Record 1 of Set 15 | chicama
# Processing Record 2 of Set 15 | whitehorse
# Processing Record 3 of Set 15 | san juan nepomuceno
# Processing Record 4 of Set 15 | sri aman
# Processing Record 5 of Set 15 | northam
# Processing Record 6 of Set 15 | jumla
# Processing Record 7 of Set 15 | milas
# Processing Record 8 of Set 15 | mazamari
# Processing Record 9 of Set 15 | ati
# Processing Record 10 of Set 15 | muskogee
# Processing Record 11 of Set 15 | lusambo
# Processing Record 12 of Set 15 | larsnes
# Processing Record 13 of Set 15 | durres
# Processing Record 14 of Set 15 | ameca
# Processing Record 15 of Set 15 | grindavik
# Processing Record 16 of Set 15 | strezhevoy
# Processing Record 17 of Set 15 | pringsewu
# Processing Record 18 of Set 15 | tocopilla
# Processing Record 19 of Set 15 | tartki
# City not found. Skipping...
# Processing Record 20 of Set 15 | yauya
# Processing Record 21 of Set 15 | san vicente de canete
# Processing Record 22 of Set 15 | kismayo
# Processing Record 23 of Set 15 | gigmoto
# Processing Record 24 of Set 15 | gorontalo
# Processing Record 25 of Set 15 | salym
# Processing Record 26 of Set 15 | aykhal
# Processing Record 27 of Set 15 | nuuk
# Processing Record 28 of Set 15 | esmeraldas
# Processing Record 29 of Set 15 | viedma
# Processing Record 30 of Set 15 | espanola
# Processing Record 31 of Set 15 | santa brigida
# Processing Record 32 of Set 15 | ephrata
# Processing Record 33 of Set 15 | hamilton
# Processing Record 34 of Set 15 | bogande
# Processing Record 35 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 15 | neuquen
# Processing Record 37 of Set 15 | pitkyaranta
# Processing Record 38 of Set 15 | yantal
# Processing Record 39 of Set 15 | seoul
# Processing Record 40 of Set 15 | goure
# Processing Record 41 of Set 15 | nyurba
# Processing Record 42 of Set 15 | zhaodong
# Processing Record 43 of Set 15 | parakou
# Processing Record 44 of Set 15 | yerbogachen
# Processing Record 45 of Set 15 | thohoyandou
# Processing Record 46 of Set 15 | westlock
# Processing Record 47 of Set 15 | comodoro rivadavia
# Processing Record 48 of Set 15 | giyani
# Processing Record 49 of Set 15 | sao bernardo
# Processing Record 50 of Set 15 | abu kamal
# Processing Record 1 of Set 16 | namtsy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           Hobart -42.88  147.33      50.0        93          90        8.05
# 1             Hilo  19.73 -155.09      82.4        61           1        4.70
# 2  Bambous Virieux -20.34   57.76      69.8        88          40        1.12
# 3         Khatanga  71.97  102.50      17.6        98          81       10.89
# 4         Nanakuli  21.39 -158.15      82.4        78          20        4.70
#
#   Current Description Country                 Date
# 0       moderate rain      AU  2020-10-03 19:23:15
# 1           clear sky      US  2020-10-03 19:21:56
# 2    scattered clouds      MU  2020-10-03 19:20:52
# 3       broken clouds      RU  2020-10-03 19:21:03
# 4          few clouds      US  2020-10-03 19:21:40

# %%
new_column_order = ["City", "Country", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#                    City Country    Lat     Lng  Max Temp  Humidity  \
# 0                Hobart      AU -42.88  147.33     50.00        93
# 1                  Hilo      US  19.73 -155.09     82.40        61
# 2       Bambous Virieux      MU -20.34   57.76     69.80        88
# 3              Khatanga      RU  71.97  102.50     17.60        98
# 4              Nanakuli      US  21.39 -158.15     82.40        78
# ..                  ...     ...    ...     ...       ...       ...
# 681  Comodoro Rivadavia      AR -45.87  -67.50     66.20        45
# 682              Giyani      ZA -23.30   30.72     69.46        74
# 683        Sao Bernardo      BR  -3.36  -42.42     90.23        44
# 684           Abu Kamal      SY  34.45   40.92     75.97        28
# 685              Namtsy      RU  62.72  129.67     32.00        95
#
#      Cloudiness  Wind Speed Current Description
# 0            90        8.05       moderate rain
# 1             1        4.70           clear sky
# 2            40        1.12    scattered clouds
# 3            81       10.89       broken clouds
# 4            20        4.70          few clouds
# ..          ...         ...                 ...
# 681           0       13.87           clear sky
# 682           0        2.68           clear sky
# 683          87        9.22     overcast clouds
# 684           0        5.93           clear sky
# 685           0        6.71           clear sky
#
# [686 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
